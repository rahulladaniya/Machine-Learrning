# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('c:\\Users\\rahul\\Downloads\\CreditCard_data.csv')

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
df.drop('CUST_ID',axis=1,inplace=True)

# %%
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %%
plt.figure(figsize=(20,40))
for i,col in enumerate(df.columns):
    plt.subplot(9,2,i+1)
    sns.histplot(df[col],kde=True)
    sns.rugplot(df[col],height=.1,color='orange')
plt.show()

# %%
df.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
print(round((df.isnull().sum()/len(df))*100,2))
# Out:
# BALANCE                             0.00
# BALANCE_FREQUENCY                   0.00
# PURCHASES                           0.00
# ONEOFF_PURCHASES                    0.00
# INSTALLMENTS_PURCHASES              0.00
# CASH_ADVANCE                        0.00
# PURCHASES_FREQUENCY                 0.00
# ONEOFF_PURCHASES_FREQUENCY          0.00
# PURCHASES_INSTALLMENTS_FREQUENCY    0.00
# CASH_ADVANCE_FREQUENCY              0.00
# CASH_ADVANCE_TRX                    0.00
# PURCHASES_TRX                       0.00
# CREDIT_LIMIT                        0.01
# PAYMENTS                            0.00
# MINIMUM_PAYMENTS                    3.50
# PRC_FULL_PAYMENT                    0.00
# TENURE                              0.00
# dtype: float64

# %%
df.dropna(inplace=True)

# %%
print(round((df.isnull().sum()/len(df))*100,2))
# Out:
# BALANCE                             0.0
# BALANCE_FREQUENCY                   0.0
# PURCHASES                           0.0
# ONEOFF_PURCHASES                    0.0
# INSTALLMENTS_PURCHASES              0.0
# CASH_ADVANCE                        0.0
# PURCHASES_FREQUENCY                 0.0
# ONEOFF_PURCHASES_FREQUENCY          0.0
# PURCHASES_INSTALLMENTS_FREQUENCY    0.0
# CASH_ADVANCE_FREQUENCY              0.0
# CASH_ADVANCE_TRX                    0.0
# PURCHASES_TRX                       0.0
# CREDIT_LIMIT                        0.0
# PAYMENTS                            0.0
# MINIMUM_PAYMENTS                    0.0
# PRC_FULL_PAYMENT                    0.0
# TENURE                              0.0
# dtype: float64

# %%
df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 4      817.714335           1.000000      16.00             16.00
# 5     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8943     5.871712           0.500000      20.90             20.90
# 8945    28.493517           1.000000     291.12              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 4                       0.00      0.000000             0.083333
# 5                    1333.28      0.000000             0.666667
# ...                      ...           ...                  ...
# 8943                    0.00      0.000000             0.166667
# 8945                  291.12      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 4                       0.083333                          0.000000
# 5                       0.000000                          0.583333
# ...                          ...                               ...
# 8943                    0.166667                          0.000000
# 8945                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 4                   0.000000                 0              1        1200.0
# 5                   0.000000                 0              8        1800.0
# ...                      ...               ...            ...           ...
# 8943                0.000000                 0              1         500.0
# 8945                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 4      678.334763        244.791237          0.000000      12
# 5     1400.057770       2407.246035          0.000000      12
# ...           ...               ...               ...     ...
# 8943    58.644883         43.473717          0.000000       6
# 8945   325.594462         48.886365          0.500000       6
# 8947    81.270775         82.418369          0.250000       6
# 8948    52.549959         55.755628          0.250000       6
# 8949    63.165404         88.288956          0.000000       6
#
# [8636 rows x 17 columns]

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
df_new=scaler.fit_transform(df)

# %%
from sklearn.cluster import KMeans

# %%
List = []
for k in range(1,11):
    kmeans = KMeans(n_clusters=k, init= "random",max_iter = 300, random_state = 1, n_init = 10) 
    kmeans.fit(df_new)
    List.append(kmeans.inertia_)
from kneed import KneeLocator
kl = KneeLocator(range(1,11), List, curve='convex', direction='decreasing')
kl.elbow
plt.style.use("fivethirtyeight")
plt.plot(range(1,11),List)
plt.xticks(range(1,11))
plt.ylabel("Interia")
plt.axvline(x=kl.elbow, color='b', label='axvline - full height', ls='--')
plt.show()

# %%
from sklearn.metrics import silhouette_score
silhouette_coefficients = []
for k in range (2,11):
    kmeans = KMeans(n_clusters=k,init= "random", random_state = 1)
    kmeans.fit(df_new)
    score = silhouette_score(df_new, kmeans.labels_)
    silhouette_coefficients.append(score)
plt.style.use("fivethirtyeight")
plt.plot(range(2,11), silhouette_coefficients)
plt.xticks(range(2,11))
plt.xlabel("Number of Clusters")
plt.ylabel("silhouette coefficients")
plt.show()

# %%
max(silhouette_coefficients)
# Out:
# np.float64(0.24772468062186503)

# %%
from sklearn.metrics import calinski_harabasz_score
calinski_harabaz = []
for k in range (2,11):
    kmeans = KMeans(n_clusters=k,init= "random", random_state = 1)
    kmeans.fit(df_new)
    metrics.calinski_harabasz_score(df_new, kmeans.labels_)
    calinski_harabaz.append(calinski_harabasz_score(df, kmeans.labels_))
plt.style.use("fivethirtyeight")
plt.plot(range(2,11), calinski_harabaz)
plt.xticks(range(2,11))
plt.xlabel("Number of Clusters")
plt.ylabel("calinski_harabasz")
plt.show()

# %% [markdown]
# ### So 3 cluster with silhouette score = 0.24772468062186503,  is the best for k-mean modeling

# %%
kmeans = KMeans(n_clusters=3,init= "random", random_state = 1)
kmeans.fit(df_new)
labels = kmeans.labels_

# %%
cluster_centers = pd.DataFrame(data = kmeans.cluster_centers_,columns=df.columns)
cluster_centers
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0 -0.365492          -0.169454  -0.235437         -0.206549
# 1  1.154015           0.311574  -0.294636         -0.210840
# 2  0.296491           0.419350   1.500378          1.256183
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0               -0.176944     -0.310721            -0.063584
# 1               -0.309208      1.379980            -0.655172
# 2                1.238339     -0.251128             1.131288
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   -0.238023                         -0.050179
# 1                   -0.314625                         -0.562268
# 2                    1.537992                          0.949828
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0               -0.333248         -0.299384      -0.246605     -0.342944
# 1                1.557873          1.341259      -0.374606      0.604526
# 2               -0.367531         -0.256635       1.654796      0.881540
#
#    PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT    TENURE
# 0 -0.288098         -0.134189          0.012867 -0.024804
# 1  0.447438          0.379752         -0.423470 -0.140363
# 2  0.816759          0.164283          0.472497  0.295974

# %%
cluster_centers = scaler.inverse_transform(cluster_centers)
cluster_centers = pd.DataFrame(data = cluster_centers, columns = [df.columns])
cluster_centers
# Out:
#        BALANCE BALANCE_FREQUENCY    PURCHASES ONEOFF_PURCHASES  \
# 0   835.355363          0.859842   515.246236       257.029218
# 1  4019.406242          0.959744   386.962299       249.802092
# 2  2222.507896          0.982128  4276.725686      2720.577565
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0             258.551537   335.033088            0.470487
# 1             137.240304  3921.575245            0.233112
# 2            1556.638317   461.448921            0.949929
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.134493                         0.348846
# 1                   0.111510                         0.144998
# 2                   0.667362                         0.746918
#
#   CASH_ADVANCE_FREQUENCY CASH_ADVANCE_TRX PURCHASES_TRX CREDIT_LIMIT  \
# 0               0.070362         1.244547      8.823960  3267.250100
# 1               0.451952        12.584845      5.601036  6734.070301
# 2               0.063444         1.540033     56.699346  7747.671569
#
#       PAYMENTS MINIMUM_PAYMENTS PRC_FULL_PAYMENT     TENURE
# 0   946.216959       545.951742         0.163115  11.501875
# 1  3086.363498      1765.239837         0.033849  11.350389
# 2  4160.953030      1254.054215         0.299283  11.922386

# %%
df_cluster_with_kmean = pd.concat([df, pd.DataFrame({'cluster': labels})], axis = 1)
df_cluster_with_kmean.dropna(inplace=True)
df_cluster_with_kmean.reset_index()
# Out:
#       index      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0         0    40.900749           0.818182      95.40              0.00
# 1         1  3202.467416           0.909091       0.00              0.00
# 2         2  2495.148862           1.000000     773.17            773.17
# 3         4   817.714335           1.000000      16.00             16.00
# 4         5  1809.828751           1.000000    1333.28              0.00
# ...     ...          ...                ...        ...               ...
# 8334   8631   553.901465           1.000000     458.76              0.00
# 8335   8632    70.162707           0.636364     599.00              0.00
# 8336   8633   942.329974           1.000000     450.00            450.00
# 8337   8634   683.188651           1.000000      85.00             85.00
# 8338   8635     4.107485           0.181818      52.50              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00      0.000000             0.083333
# 4                    1333.28      0.000000             0.666667
# ...                      ...           ...                  ...
# 8334                  458.76      0.000000             1.000000
# 8335                  599.00      0.000000             0.500000
# 8336                    0.00    722.690339             0.166667
# 8337                    0.00      0.000000             0.083333
# 8338                   52.50      0.000000             0.166667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.000000                          0.583333
# ...                          ...                               ...
# 8334                    0.000000                          1.000000
# 8335                    0.000000                          0.416667
# 8336                    0.166667                          0.000000
# 8337                    0.083333                          0.000000
# 8338                    0.000000                          0.083333
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000               0.0            2.0        1000.0
# 1                   0.250000               4.0            0.0        7000.0
# 2                   0.000000               0.0           12.0        7500.0
# 3                   0.000000               0.0            1.0        1200.0
# 4                   0.000000               0.0            8.0        1800.0
# ...                      ...               ...            ...           ...
# 8334                0.000000               0.0           12.0        1000.0
# 8335                0.000000               0.0            6.0        1000.0
# 8336                0.166667               2.0            3.0        1200.0
# 8337                0.000000               0.0            1.0        3000.0
# 8338                0.000000               0.0            2.0         500.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  cluster
# 0      201.802084        139.509787          0.000000    12.0      0.0
# 1     4103.032597       1072.340217          0.222222    12.0      1.0
# 2      622.066742        627.284787          0.000000    12.0      0.0
# 3      678.334763        244.791237          0.000000    12.0      0.0
# 4     1400.057770       2407.246035          0.000000    12.0      2.0
# ...           ...               ...               ...     ...      ...
# 8334   157.770746        257.530999          0.000000    12.0      0.0
# 8335  1007.348156        139.860070          1.000000    12.0      0.0
# 8336   281.028562        170.661135          0.000000     6.0      0.0
# 8337   447.237766        214.535254          0.000000    12.0      0.0
# 8338    82.529481        163.602544          0.000000    12.0      0.0
#
# [8339 rows x 19 columns]

# %%
sns.countplot(x=df_cluster_with_kmean.cluster)
plt.show()

# %%
# from sklearn_extra.cluster import KMedoids
# List = []
# for k in range(1,11):#this range is optional
#     kmedoids = KMedoids(n_clusters=k,init= "random", random_state =5 ) 
#     kmedoids.fit(df_new)
#     List.append( kmedoids.inertia_)
    
# from kneed import KneeLocator
# kl = KneeLocator(range(1,11), List, curve='convex', direction='decreasing')
# kl.elbow
# plt.style.use("fivethirtyeight")
# plt.plot(range(1,11),List)
# plt.xticks(range(1,11))
# plt.ylabel("Interia")
# plt.axvline(x=kl.elbow, color='b', label='axvline - full height', ls='--')
# plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
print("max silhouette score for Agglomerative method is:",max(sil_Hierarch))
# Out:
# max silhouette score for Agglomerative method is: 0.1865256797594413

# %%
from sklearn import metrics
from sklearn.metrics import calinski_harabasz_score

# %%
df_new
# Out:
# array([[-0.74462486, -0.37004679, -0.42918384, ..., -0.30550763,
#         -0.53772694,  0.35518066],
#        [ 0.76415211,  0.06767893, -0.47320819, ...,  0.08768873,
#          0.21238001,  0.35518066],
#        [ 0.42660239,  0.50540465, -0.11641251, ..., -0.09990611,
#         -0.53772694,  0.35518066],
#        ...,
#        [-0.75297728, -0.29709491, -0.40657175, ..., -0.32957217,
#          0.30614422, -4.22180042],
#        [-0.75772142, -0.29709491, -0.47320819, ..., -0.34081076,
#          0.30614422, -4.22180042],
#        [-0.58627829, -1.09958965,  0.03129519, ..., -0.32709767,
#         -0.53772694, -4.22180042]])

# %%
from sklearn.preprocessing import normalize

# %%
df_new2=pd.DataFrame(normalize(df_new))

# %%
df_new2
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.311806 -0.154954 -0.179717 -0.150396 -0.148581 -0.196246 -0.343691
# 1     0.215652  0.019100 -0.133545 -0.101359 -0.129489  0.724875 -0.348852
# 2     0.121694  0.144174 -0.033208  0.028501 -0.130890 -0.133690  0.358313
# 3    -0.156537  0.211587 -0.195017 -0.146385 -0.192092 -0.196202 -0.430561
# 4     0.045686  0.231939  0.065195 -0.164825  0.456538 -0.215074  0.195195
# ...        ...       ...       ...       ...       ...       ...       ...
# 8631 -0.145686 -0.363972 -0.088705 -0.066352 -0.087801 -0.089679 -0.157057
# 8632 -0.147255  0.099159 -0.066484 -0.070466 -0.027749 -0.091949  0.246439
# 8633 -0.156509 -0.061752 -0.084507 -0.074653 -0.062647 -0.097412  0.174744
# 8634 -0.153722 -0.060273 -0.096002 -0.072865 -0.093087 -0.091582 -0.250781
# 8635 -0.115235 -0.216128  0.006151  0.056992 -0.090187 -0.080345  0.083602
#
#             7         8         9         10        11        12        13  \
# 0    -0.287374 -0.300313 -0.285562 -0.200761 -0.216751 -0.403071 -0.227772
# 1    -0.193676 -0.261474  0.157198  0.028012 -0.168495  0.191114  0.224880
# 2     0.754993 -0.264303 -0.194536 -0.136766 -0.034365  0.232162 -0.113964
# 3    -0.171033 -0.387886 -0.285498 -0.200715 -0.233329 -0.380097 -0.159155
# 4    -0.314946  0.247302 -0.312960 -0.220022 -0.128189 -0.341406 -0.060632
# ...        ...       ...       ...       ...       ...       ...       ...
# 8631 -0.025027 -0.177294 -0.130494 -0.091742 -0.106649 -0.210341 -0.113500
# 8632 -0.134646  0.228945 -0.133797 -0.094064 -0.070388 -0.188855 -0.098373
# 8633 -0.142646  0.155522 -0.141746 -0.099653 -0.082825 -0.200075 -0.121671
# 8634 -0.139229 -0.187968  0.029221 -0.038564 -0.121127 -0.223005 -0.120759
# 8635  0.301843 -0.182111  0.190660 -0.037363  0.062191 -0.178454 -0.116279
#
#             14        15        16
# 0    -0.127929 -0.225169  0.148729
# 1     0.024747  0.059936  0.100236
# 2    -0.028500 -0.153394  0.101320
# 3    -0.109322 -0.225118  0.148696
# 4     0.298463 -0.246772  0.162999
# ...        ...       ...       ...
# 8631 -0.066206 -0.102896 -0.807858
# 8632 -0.067434  0.225630 -0.828306
# 8633 -0.068503  0.063633 -0.877516
# 8634 -0.069142  0.062109 -0.856496
# 8635 -0.064292 -0.105692 -0.829811
#
# [8636 rows x 17 columns]

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 2) 
X_principal = pca.fit_transform(df_new2) 
X_principal = pd.DataFrame(X_principal) 
X_principal.columns = ['P1', 'P2'] 
  
X_principal.head(2)
# Out:
#          P1        P2
# 0 -0.481788 -0.692991
# 1 -0.537375  0.527807

# %%
import scipy.cluster.hierarchy as shc

# %%
plt.figure(figsize =(6, 6)) 
plt.title('Visualising the data') 
Dendrogram = shc.dendrogram((shc.linkage(X_principal, method ='ward')))

# %%
sil_Hierarch = []
for k in range(2,20):#
    Hierarch = AgglomerativeClustering(n_clusters = k,linkage='ward') 
    score = silhouette_score(df_new, Hierarch.fit_predict(df_new),metric='euclidean')
    sil_Hierarch.append(score)
plt.style.use("fivethirtyeight")
plt.plot(range(2,20), sil_Hierarch)
plt.xticks(range(2,20))
plt.xlabel("Number of Clusters")
plt.ylabel("silhouette coefficients")
plt.show()

# %%
calinski_harabaz = []
for k in range (2,11):
    Hierarch = AgglomerativeClustering(n_clusters = k, linkage='ward')
    score = metrics.calinski_harabasz_score(df_new, Hierarch.fit_predict(df_new))
    calinski_harabaz.append(score)
plt.style.use("fivethirtyeight")
plt.plot(range(2,11), calinski_harabaz)
plt.xticks(range(2,11))
plt.xlabel("Number of Clusters")
plt.ylabel("calinski_harabasz")
plt.show()

# %%
silhouette_scores = [] 

for n_cluster in range(2, 8):
    silhouette_scores.append( 
        silhouette_score(X_principal, AgglomerativeClustering(n_clusters = n_cluster).fit_predict(X_principal))) 
    
# Plotting a bar graph to compare the results 
k = [2, 3, 4, 5, 6,7] 
plt.bar(k, silhouette_scores) 
plt.xlabel('Number of clusters', fontsize = 10) 
plt.ylabel('Silhouette Score', fontsize = 10) 
plt.show()

# %%
plt.scatter(X_principal['P1'], X_principal['P2'], c = AgglomerativeClustering(n_clusters = 3).fit_predict(X_principal), cmap =plt.cm.winter) 
plt.show()
