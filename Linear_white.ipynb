# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:\\Users\\rahul\\Downloads\\wine+quality\\winequality-white.csv',delimiter=';')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
X=df.iloc[:,:11]
y=df.iloc[:,11:]

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
y
# Out:
#       quality
# 0           6
# 1           6
# 2           6
# 3           6
# 4           6
# ...       ...
# 4893        6
# 4894        5
# 4895        6
# 4896        7
# 4897        6
#
# [4898 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_train
# Out:
# array([[-0.54987946,  0.10802059,  0.90421574, ..., -1.17885395,
#         -0.95161186, -1.16015744],
#        [-0.54987946,  2.68432745, -0.60752263, ...,  0.20596905,
#          2.05685671,  2.08537806],
#        [-0.30915578, -0.38742304, -0.52353717, ...,  0.33785695,
#          0.16581933, -1.07901905],
#        ...,
#        [ 1.25554814,  0.50437549, -0.4395517 , ..., -0.25563862,
#         -0.95161186, -1.4035726 ],
#        [ 2.45916654, -0.18924559, -0.01962438, ..., -0.38752652,
#         -0.2639619 ,  0.21919515],
#        [ 1.25554814,  2.28797255,  0.06436109, ..., -0.65130233,
#          0.16581933, -0.42991195]])

# %%
y_train=scaler.fit_transform(y_train)
y
# Out:
#       quality
# 0           6
# 1           6
# 2           6
# 3           6
# 4           6
# ...       ...
# 4893        6
# 4894        5
# 4895        6
# 4896        7
# 4897        6
#
# [4898 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import cross_val_score

# %%
mse=cross_val_score(regressor,X_train,y_train,scoring='neg_mean_squared_error',cv=10)

# %%
np.mean(mse)
# Out:
# np.float64(-0.7149133766510707)

# %%
pred=regressor.predict(X_test)
# Out:
# d:\Virtual\rj\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
print(pred)
# Out:
# [[ 2.18698556]
#  [ 7.29401733]
#  [ 4.93821615]
#  ...
#  [ 6.12154576]
#  [13.46627656]
#  [ 8.11597621]]

# %%
import seaborn as sns
sns.displot(pred-y_test,kind='kde')

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(pred,y_test)
print(score)
# Out:
# -0.4632911003519584

# %%
from sklearn.linear_model import Ridge
ridge_regression=Ridge()

# %%
ridge_regression
# Out:
# Ridge()

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'alpha':[1,2,5,10,20,30,40,50,60,60,70,80,90]}
ridgecv=GridSearchCV(ridge_regression,parameters,scoring='neg_mean_squared_error',cv=5)
ridgecv.fit(X_train,y_train)
# Out:
# d:\Virtual\rj\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1, 2, 5, 10, 20, 30, 40, 50, 60, 60, 70, 80,
#                                    90]},
#              scoring='neg_mean_squared_error')

# %%
print(ridgecv.best_params_)
# Out:
# {'alpha': 2}

# %%
print(ridgecv.best_score_)
# Out:
# -0.7164909965287521
